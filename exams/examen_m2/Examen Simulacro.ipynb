# %%
import pandas as pd
import os

data_path = '../../Data/Telco Churn/'
df = pd.read_csv(data_path+'churn-bigml-80.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ## Función auxiliar:
# train_test_split de sklearn, nos ayuda a partir el dataset en dos, para tener una partición de entrenamiento y una partición de validación. Recuérden utilizarla.

# %%
df['Voice mail plan'].value_counts(1)
# Out:
# No     0.725056
# Yes    0.274944
# Name: Voice mail plan, dtype: float64
